# %%
import numpy as np 
import pandas as pd 
from numpy import array
import matplotlib.pyplot as plt 
from sklearn.preprocessing import LabelEncoder

# %%
original = pd.read_csv('cases.csv')
# Out:
# C:\Users\Yuwan\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (5,15,23,43,44,51,53,55,63,67,71,73,74,79,92,107,108,126,127,130,132,144) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
reversed_index=original.loc[ ( (original['Has Reverse'] == 'Yes') & (original['Has Affirm'].isnull() ))].index#
partial_index=original.loc[ ( (original['Has Reverse']== 'Yes') & (original['Has Affirm']== 'Yes' ))].index#
nan_index=original.loc[ ( (original['Has Reverse'].isnull()) & (original['Has Affirm'].isnull() ))].index#
affirm_index=original.loc[ ( (original['Has Affirm'] == 'Yes') & (original['Has Reverse'].isnull() ))].index#

# %%
new=original[['Case Id','Case Type','Case Name','Decision Date','Lower Ct Judge']]
new['case status']=''
# Out:
# C:\Users\Yuwan\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
for i in affirm_index:
    new.at[i,'case status']='Affirm'
for i in reversed_index:
    new.at[i,'case status']='Reverse'
for i in partial_index:
    new.at[i,'case status']='Partially'
#delete rows with nan status 
new.drop(nan_index,inplace=True)
new.reset_index(drop=True,inplace=True)
# Out:
# C:\Users\Yuwan\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
# delete rows with NAN judge name
drop_nan_jud=new[pd.notnull(new['Lower Ct Judge'])]
drop_nan_jud.reset_index(drop=True,inplace=True)
drop_nan_jud
# Out:
#           Case Id Case Type  \
# 0     2008-P-0001     Civil
# 1     2008-P-1002     Civil
# 2     2008-P-1006     Civil
# 3     2008-P-1007     Civil
# 4     2008-P-1014     Civil
# 5     2008-P-1019     Civil
# 6     2008-P-1021     Civil
# 7     2008-P-1026     Civil
# 8     2008-P-1027     Civil
# 9     2008-P-1029     Civil
# 10    2008-P-1030     Civil
# 11    2008-P-0104     Civil
# 12    2008-P-1046     Civil
# 13    2008-P-0105     Civil
# 14    2008-P-1051     Civil
# 15    2008-P-1052     Civil
# 16    2008-P-1053     Civil
# 17    2008-P-1054     Civil
# 18    2008-P-1055     Civil
# 19    2008-P-1060     Civil
# 20    2008-P-1066     Civil
# 21    2008-P-1068     Civil
# 22    2008-P-1070     Civil
# 23    2008-P-1072     Civil
# 24    2008-P-1077     Civil
# 25    2008-P-1079     Civil
# 26    2008-P-1083     Civil
# 27    2008-P-1086     Civil
# 28    2008-P-1088     Civil
# 29    2008-P-1089     Civil
# ...           ...       ...
# 4747    SJC-12203     Civil
# 4748    SJC-12204     Civil
# 4749    SJC-12205     Civil
# 4750    SJC-12211     Civil
# 4751    SJC-12223     Civil
# 4752    SJC-12226     Civil
# 4753    SJC-12228     Civil
# 4754    SJC-12231     Civil
# 4755    SJC-12242     Civil
# 4756    SJC-12250     Civil
# 4757    SJC-12253     Civil
# 4758    SJC-12261     Civil
# 4759    SJC-12262     Civil
# 4760    SJC-12266     Civil
# 4761    SJC-12267     Civil
# 4762    SJC-12270     Civil
# 4763    SJC-12287     Civil
# 4764    SJC-12288     Civil
# 4765    SJC-12291     Civil
# 4766    SJC-12293     Civil
# 4767    SJC-12298     Civil
# 4768    SJC-12304     Civil
# 4769    SJC-12309     Civil
# 4770    SJC-12315     Civil
# 4771    SJC-12323     Civil
# 4772    SJC-12325     Civil
# 22             Robert B. Calagione, J.      Affirm
# 23            Judith Nelson Dilday, J.      Affirm
# 24              Christina L. Harms, J.      Affirm
# 25              Alexander H. Sands, J.      Affirm
# 26              Alexander H. Sands, J.      Affirm
# 27                Leon J. Lombardi, J.      Affirm
# 28                Patrick F. Brady, J.     Reverse
# 29                 Gordon H. Piper, J.      Affirm
# ...                                ...         ...
# 4747             Raffi N. Yessayan, J.     Reverse
# 4748                Linda E. Giles, J.     Reverse
# 4749                Shannon Frison, J.     Reverse
# 4750               Charles J. Hely, J.      Affirm
# 4751             Mary Ann Sahagian, J.      Affirm
# 4752              Robert N. Tochka, J.   Partially
# 4753            Patricia A. Gorman, J.      Affirm
# 4754           Frances A. McIntyre, J.     Reverse
# 4755            Geraldine S. Hines, J.      Affirm
# 4756           William F. Sullivan, J.      Affirm
# 4757              Robert B. Foster, J.      Affirm
# 4758              Frank M. Gaziano, J.      Affirm
# 4759                 David A. Lowy, J.      Affirm
# 4760                Peter B. Krupp, J.      Affirm
# 4761             Thomas S. Barrett, J.      Affirm
# 4762           Christopher J. Muse, J.      Affirm
# 4763           Kenneth W. Salinger, J.     Reverse
# 4764      Edward J. McDonough, Jr., J.      Affirm
# 4765                Paul D. Wilson, J.     Reverse
# 4766             Richard T. Tucker, J.     Reverse
# 4767            Patricia A. Gorman, J.      Affirm
# 4768            Alexander H. Sands, J.      Affirm
# 4769  Rebekah J. Crampton Kamukala, J.      Affirm
# 4770              Dennis J. Curran, J.     Reverse
# 4771     Cornelius J. Moriarty, II, J.      Affirm
# 4772              Robert B. Foster, J.      Affirm
# 4773              Peter M. Lauriat, J.      Affirm
# 4774                 David A. Lowy, J.      Affirm
# 4775             Elspeth B. Cypher, J.      Affirm
# 4776                Brian A. Davis, J.   Partially
#
# [4777 rows x 6 columns]

# %%
# analysis every judges reversed ratio, affirmed ratio and partial ratio
#{"x":[reversed_num, affirmed_num, partial_num]}
judge_count = {} 
for i, j in drop_nan_jud.iterrows():
    jud_name=j['Lower Ct Judge']
    status=j['case status']    
    if jud_name not in judge_count:
        if status=='Reverse':
            judge_count[jud_name]=[1,0,0,1]
        elif status=='Affirm':
            judge_count[jud_name]=[0,1,0,1]
        else:
            judge_count[jud_name]=[0,0,1,1]
              
    else:
        if status=='Reverse':
            judge_count[jud_name][0]=judge_count[jud_name][0]+1
            judge_count[jud_name][3]=judge_count[jud_name][3]+1
        elif status=='Affirm':
            judge_count[jud_name][1]=judge_count[jud_name][1]+1
            judge_count[jud_name][3]=judge_count[jud_name][3]+1
        else:
            judge_count[jud_name][2]=judge_count[jud_name][2]+1
            judge_count[jud_name][3]=judge_count[jud_name][3]+1
            
judge_sorted=sorted(judge_count.items(), key=lambda x: x[1][3], reverse=True)   
judge_count_sorted = {}
[judge_count_sorted.update({k:v}) for k,v in judge_sorted]
print(judge_count_sorted)
# Out:
 'Daniel M. Wrenn, J.': [2, 23, 2, 27], 'Francis X. Spina, J.': [0, 24, 3, 27], 'Bertha D. Josephson, J.': [3, 23, 0, 26], 'Karyn F. Scheier, J.': [1, 24, 1, 26], 'Cornelius J. Moriarty, II, J.': [3, 21, 2, 26], 'Kimberly S. Budd, J.': [3, 21, 2, 26], 'Robert B. Foster, J.': [0, 23, 3, 26], 'Richard J. Chin, J.': [4, 21, 0, 25], 'John S. McCann, J.': [1, 22, 2, 25], 'Thomas F. McGuire, Jr., J.': [0, 24, 1, 25], 'Spencer M. Kagan, J.': [1, 23, 0, 24], 'Randy J. Kaplan, J.': [0, 23, 1, 24], 'Timothy F. Sullivan, J.': [5, 18, 1, 24], 'Ralph D. Gants, C.J.': [0, 21, 2, 23], 'Maureen B. Hogan, J.': [3, 20, 0, 23], 'Regina L. Quinlan, J.': [2, 20, 1, 23], 'Peter W. Agnes, Jr., J.': [3, 19, 1, 23], 'Lucille A. DiLeo, J.': [1, 20, 1, 22], 'James R. Lemire, J.': [0, 22, 0, 22], 'Catherine P. Sabaitis, J.': [1, 21, 0, 22], 'Maynard M. Kirpalani, J.': [1, 17, 4, 22], 'Eleanor S. Garsh, J.': [1, 19, 1, 21], 'Constance M. Sweeney, J.': [1, 18, 2, 21], 'William F. McSweeny, III, J.': [0, 20, 1, 21], 'John A. Agostini, J.': [0, 19, 1, 20], 'Leila R. Kern, J.': [1, 19, 0, 20], 'Susan D. Ricci, J.': [1, 18, 1, 20], 'Edward F. Donnelly, Jr., J.': [3, 17, 0, 20], 'Virginia M. Ward, J.': [5, 14, 1, 20], 'Nancy S. Holtz, J.': [2, 15, 3, 20], 'Robert L. Ullmann, J.': [3, 15, 2, 20], 'Frank M. Gaziano, J.': [0, 18, 1, 19], 'Diane M. Kottmyer, J.': [0, 18, 1, 19], 'Nancy Staffier-Holtz, J.': [3, 14, 2, 19], 'Maureen H. Monks, J.': [0, 18, 1, 19], 'Robert A. Scandurra, J.': [1, 18, 0, 19], 'Kenneth W. Salinger, J.': [3, 15, 1, 19], 'Brian  ...

# %%
#Create Dataframe with columns, name of judge and its statistics in order to graph it
judges_data_10yr = pd.DataFrame.from_dict(judge_count_sorted).transpose()
judges_data_10yr.rename(columns = {0:'Reversed',1:'Affirmed',2:'Partial',3:'Total'}, inplace = True)
judges_data_10yr
# Out:
#                                Reversed  Affirmed  Partial  Total
# Dennis J. Curran, J.                  5        86        3     94
# Alexander H. Sands, J.                5        57        5     67
# Patrick F. Brady, J.                  5        57        5     67
# Robert A. Cornetta, J.                8        53        3     64
# Thomas R. Murtagh, J.                 4        52        6     62
# Christopher J. Muse, J.               6        50        4     60
# Linda E. Giles, J.                   10        47        3     60
# Geraldine S. Hines, J.                5        50        2     57
# Bonnie H. MacLeod-Mancuso, J.         4        50        2     56
# Keith C. Long, J.                     2        50        0     52
# Janet L. Sanders, J.                  3        45        3     51
# Peter M. Lauriat, J.                  3        44        4     51
# Gordon H. Piper, J.                   1        47        2     50
# John C. Cratsley, J.                  7        40        3     50
# Timothy Q. Feeley, J.                 3        43        4     50
# Frances A. McIntyre, J.               4        40        5     49
# Bruce R. Henry, J.                    1        43        4     48
# Charles W. Trombly, J.                3        44        1     48
# Elizabeth M. Fahey, J.               10        36        2     48
# Douglas H. Wilkins, J.                2        43        1     46
# Judith Fabricant, J.                  1        42        2     45
# Richard T. Moses, J.                  3        39        2     44
# Thomas P. Billings, J.                3        36        4     43
# Thayer Fremont-Smith, J.              4        37        1     42
# S. Jane Haggerty, J.                  0        42        0     42
# Richard E. Welch, III, J.             2        37        3     42
# Charles J. Hely, J.                   2        37        2     41
# Christine M. Roach, J.                1        36        4     41
# Robert C. Rufo, J.                    4        33        3     40
# Thomas E. Connolly, J.                1        37        1     39
# ...                                 ...       ...      ...    ...
# Michael E. Mulcahy, J.                0         1        0      1
# Debra Shopteese, J.                   0         1        0      1
# James W. Coffey, J.                   0         1        0      1
# Rosemary Minehan, J.                  0         1        0      1
# Jonathan R. Tynes, J.                 0         1        0      1
# William J. O'Grady, J.                0         1        0      1
# Gregory I. Massing, J.                0         1        0      1
# Julie J. Bernard, J.                  0         1        0      1
# Toby S. Mooney, J.                    0         1        0      1
# Serge Georges, Jr., J.                0         1        0      1
# Andrew M. D'Angelo, J.                0         1        0      1
# Tobin N. Harvey, J.                   0         1        0      1
# Emily A. Karstetter, J.               0         0        1      1
# Lynn C. Rooney, J.                    0         1        0      1
# Lynn Coffin Brendemuehl, J.           0         1        0      1
# Megan H. Christopher, J.              0         1        0      1
# Mary A. Orfanello, J.                 0         1        0      1
# Eric Neyman, J.                       0         1        0      1
# Joseph F. Leighton, Jr., J.           0         1        0      1
# James H. Wexler, J.                   0         1        0      1
# Jennifer A. Stark, J.                 0         1        0      1
# Kevin J. Finnerty, J.                 0         1        0      1
# Michael K. Callan, J.                 0         1        0      1
# Kathryn M. Bailey, J.                 0         1        0      1
# Kevin R. Connelly, J.                 0         1        0      1
# Patricia G. Curtin, J.                1         0        0      1
# William P. Hadley, J.                 1         0        0      1
# Lawrence Moniz, J.                    0         1        0      1
# John S. Spinale, J.                   0         1        0      1
# Heather M.S. Bradley, J.              0         1        0      1
#
# [387 rows x 4 columns]

# %%
def print_stats(judge_count):
    #We're given list of certain judge [number_of_reversed,number_of_affirmed,number_of_partial,total_number_of_cases]
    #Pct reversed:
    per_dic={}
    for i in judge_count.items():
        judge_name=i[0]
        lst=i[1]       
        total=lst[3]
        pct_reversed = round((lst[0]/total)*100,2)
#     #Pct affirmed
        pct_affirmed = round((lst[1]/total)*100,2)
#     #Pct partial
        pct_partial = round((lst[2]/total)*100,2)
        per_dic[judge_name]=[pct_reversed,pct_affirmed,pct_partial,total]
    return per_dic
        #print("Judge {} has {}% of cases reversed, {}% of cases affirmed, and {}% of cases partially affirmed/reversed, total #of cases N= {}".format(judge_name,pct_reversed,pct_affirmed,pct_partial,lst[3]))
judges_data_per = pd.DataFrame.from_dict(print_stats(judge_count_sorted)).transpose()
judges_data_per.rename(columns = {0:'pct_reversed%',1:'pct_affirmed%',2:'pct_partial%',3:'Total'}, inplace = True)
judges_data_per
# Out:
# Patricia G. Curtin, J.                100.00           0.00          0.00
# William P. Hadley, J.                 100.00           0.00          0.00
# Lawrence Moniz, J.                      0.00         100.00          0.00
# John S. Spinale, J.                     0.00         100.00          0.00
# Heather M.S. Bradley, J.                0.00         100.00          0.00
#
#                                Total
# Dennis J. Curran, J.            94.0
# Alexander H. Sands, J.          67.0
# Patrick F. Brady, J.            67.0
# Robert A. Cornetta, J.          64.0
# Thomas R. Murtagh, J.           62.0
# Christopher J. Muse, J.         60.0
# Linda E. Giles, J.              60.0
# Geraldine S. Hines, J.          57.0
# Bonnie H. MacLeod-Mancuso, J.   56.0
# Keith C. Long, J.               52.0
# Janet L. Sanders, J.            51.0
# Peter M. Lauriat, J.            51.0
# Gordon H. Piper, J.             50.0
# John C. Cratsley, J.            50.0
# Timothy Q. Feeley, J.           50.0
# Frances A. McIntyre, J.         49.0
# Bruce R. Henry, J.              48.0
# Charles W. Trombly, J.          48.0
# Elizabeth M. Fahey, J.          48.0
# Douglas H. Wilkins, J.          46.0
# Judith Fabricant, J.            45.0
# Richard T. Moses, J.            44.0
# Thomas P. Billings, J.          43.0
# Thayer Fremont-Smith, J.        42.0
# S. Jane Haggerty, J.            42.0
# Richard E. Welch, III, J.       42.0
# Charles J. Hely, J.             41.0
# Christine M. Roach, J.          41.0
# Robert C. Rufo, J.              40.0
# Thomas E. Connolly, J.          39.0
# ...                              ...
# Michael E. Mulcahy, J.           1.0
# Debra Shopteese, J.              1.0
# James W. Coffey, J.              1.0
# Rosemary Minehan, J.             1.0
# Jonathan R. Tynes, J.            1.0
# William J. O'Grady, J.           1.0
# Gregory I. Massing, J.           1.0
# Julie J. Bernard, J.             1.0
# Toby S. Mooney, J.               1.0
# Serge Georges, Jr., J.           1.0
# Andrew M. D'Angelo, J.           1.0
# Tobin N. Harvey, J.              1.0
# Emily A. Karstetter, J.          1.0
# Lynn C. Rooney, J.               1.0
# Lynn Coffin Brendemuehl, J.      1.0
# Megan H. Christopher, J.         1.0
# Mary A. Orfanello, J.            1.0
# Eric Neyman, J.                  1.0
# Joseph F. Leighton, Jr., J.      1.0
# James H. Wexler, J.              1.0
# Jennifer A. Stark, J.            1.0
# Kevin J. Finnerty, J.            1.0
# Michael K. Callan, J.            1.0
# Kathryn M. Bailey, J.            1.0
# Kevin R. Connelly, J.            1.0
# Patricia G. Curtin, J.           1.0
# William P. Hadley, J.            1.0
# Lawrence Moniz, J.               1.0
# John S. Spinale, J.              1.0
# Heather M.S. Bradley, J.         1.0
#
# [387 rows x 4 columns]

# %%
#firnd the judges who has reversed number at least 3 and total number of cases>12
r_sort=judges_data_10yr.sort_values(by='Reversed', ascending=False)
r_top_sort=r_sort.loc[((r_sort['Reversed']>4) & (r_sort['Total']>12)) ]
r_jud=r_top_sort.index.tolist()

# %%
#drop_nan_jud.to_csv("10yrs_civil_cases.csv")

# %%
#judges_data_per.to_csv("10yrs_civil_cases_pct.csv")

# %%
#judges_data_10yr.to_csv("10yrs_jud_descendingorder.csv")

# %%
#  reversed_most is sort by reversed number of cases
reversed_most=judges_data_per.loc[ ( judges_data_per['Total'] >12)&(judges_data_per['pct_reversed%'] >8)]
reversed_most.sort_values(by='pct_reversed%', ascending=False,inplace=True)
# find judge who has most pct reversed
pct_most=reversed_most.index.tolist()
reversed_most
# Out:
# C:\Users\Yuwan\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                pct_reversed%  pct_affirmed%  pct_partial%  \
# Virginia M. Ward, J.                   25.00          70.00          5.00
# John D. Casey, J.                      23.53          76.47          0.00
# Elizabeth M. Fahey, J.                 20.83          75.00          4.17
# Timothy F. Sullivan, J.                20.83          75.00          4.17
# C. Brian McDonald, J.                  18.75          81.25          0.00
# MaryLou Muirhead, J.                   17.65          70.59         11.76
# Linda E. Giles, J.                     16.67          78.33          5.00
# Shannon Frison, J.                     16.67          83.33          0.00
# Robert J. Kane, J.                     16.67          75.00          8.33
# Richard J. Chin, J.                    16.00          84.00          0.00
# Kenneth W. Salinger, J.                15.79          78.95          5.26
# Nancy Staffier-Holtz, J.               15.79          73.68         10.53
# Garry V. Inge, J.                      15.62          84.38          0.00
# Christina L. Harms, J.                 15.38          76.92          7.69
# Wendie I. Gershengorn, J.              15.38          76.92          7.69
# Robert L. Ullmann, J.                  15.00          75.00         10.00
# Edward F. Donnelly, Jr., J.            15.00          85.00          0.00
# C. Jeffrey Kinder, J.                  14.29          85.71          0.00
# John C. Cratsley, J.                   14.00          80.00          6.00
# Peter B. Krupp, J.                     13.33          86.67          0.00
# John P. Connor, Jr., J.                13.33          76.67         10.00
# Patricia A. Gorman, J.                 13.33          80.00          6.67
# Robert C. Cosgrove, J.                 13.16          86.84          0.00
# Maureen B. Hogan, J.                   13.04          86.96          0.00
# Peter W. Agnes, Jr., J.                13.04          82.61          4.35
# Ronald W. King, J.                     12.50          87.50          0.00
# Peter A. Velis, J.                     12.50          87.50          0.00
# Robert A. Cornetta, J.                 12.50          82.81          4.69
# John P. Cronin, J.                     11.76          82.35          5.88
# Kimberly S. Budd, J.                   11.54          80.77          7.69
# Cornelius J. Moriarty, II, J.          11.54          80.77          7.69
# Bertha D. Josephson, J.                11.54          88.46          0.00
# Diana H. Horan, J.                     11.11          83.33          5.56
# Charles T. Spurlock, J.                11.11          81.48          7.41
# Brian A. Davis, J.                     10.53          78.95         10.53
# Richard F. Connon, J.                  10.34          86.21          3.45
# Robert C. Rufo, J.                     10.00          82.50          7.50
# Nancy S. Holtz, J.                     10.00          75.00         15.00
# Christopher J. Muse, J.                10.00          83.33          6.67
# Jeffrey M. Winik, J.                    9.68          87.10          3.23
# Thayer Fremont-Smith, J.                9.52          88.10          2.38
# Elizabeth B. Donovan, J.                9.09          87.88          3.03
# Geraldine S. Hines, J.                  8.77          87.72          3.51
# Regina L. Quinlan, J.                   8.70          86.96          4.35
# David D. Kerman, J.                     8.57          82.86          8.57
# Mitchell H. Kaplan, J.                  8.57          88.57          2.86
# D. Lloyd Macdonald, J.                  8.33          86.11          5.56
# Frances A. McIntyre, J.                 8.16          81.63         10.20
# Herman J. Smith, Jr., J.                8.11          89.19          2.70
# Peter C. DiGangi, J.                    8.11          81.08         10.81
#
#                                Total
# Virginia M. Ward, J.            20.0
# John D. Casey, J.               17.0
# Elizabeth M. Fahey, J.          48.0
# Timothy F. Sullivan, J.         24.0
# C. Brian McDonald, J.           16.0
# MaryLou Muirhead, J.            17.0
# Linda E. Giles, J.              60.0
# Shannon Frison, J.              18.0
# Robert J. Kane, J.              36.0
# Richard J. Chin, J.             25.0
# Kenneth W. Salinger, J.         19.0
# Nancy Staffier-Holtz, J.        19.0
# Garry V. Inge, J.               32.0
# Christina L. Harms, J.          13.0
# Wendie I. Gershengorn, J.       13.0
# Robert L. Ullmann, J.           20.0
# Edward F. Donnelly, Jr., J.     20.0
# C. Jeffrey Kinder, J.           14.0
# John C. Cratsley, J.            50.0
# Peter B. Krupp, J.              15.0
# John P. Connor, Jr., J.         30.0
# Patricia A. Gorman, J.          15.0
# Robert C. Cosgrove, J.          38.0
# Maureen B. Hogan, J.            23.0
# Peter W. Agnes, Jr., J.         23.0
# Ronald W. King, J.              16.0
# Peter A. Velis, J.              16.0
# Robert A. Cornetta, J.          64.0
# John P. Cronin, J.              17.0
# Kimberly S. Budd, J.            26.0
# Cornelius J. Moriarty, II, J.   26.0
# Bertha D. Josephson, J.         26.0
# Diana H. Horan, J.              18.0
# Charles T. Spurlock, J.         27.0
# Brian A. Davis, J.              19.0
# Richard F. Connon, J.           29.0
# Robert C. Rufo, J.              40.0
# Nancy S. Holtz, J.              20.0
# Christopher J. Muse, J.         60.0
# Jeffrey M. Winik, J.            31.0
# Thayer Fremont-Smith, J.        42.0
# Elizabeth B. Donovan, J.        33.0
# Geraldine S. Hines, J.          57.0
# Regina L. Quinlan, J.           23.0
# David D. Kerman, J.             35.0
# Mitchell H. Kaplan, J.          35.0
# D. Lloyd Macdonald, J.          36.0
# Frances A. McIntyre, J.         49.0
# Herman J. Smith, Jr., J.        37.0
# Peter C. DiGangi, J.            37.0

# %%
# most is the name of judge who combine both absolute value and pct of reversed cases
most=[]
for i in pct_most:
    if i in r_jud:
        most.append(i)
        
#plot the data 
top_most_reversed=reversed_most.loc[most,:] 
x_data = top_most_reversed.index
y1 = top_most_reversed['pct_reversed%']
y2 =  top_most_reversed['pct_affirmed%']
y3 =  top_most_reversed['pct_partial%']
# y_data =  judges_data_10yr['Total']

plt.bar(x_data, y1, color='green', label='reversed_pct')
plt.bar(x_data, y2, bottom=y1, color='red', label='Affirmed_pct')
plt.bar(x_data, y3, bottom=y1+y2, color='blue', label='Partial_pct')
plt.legend(loc=[1, 0])
plt.title('judge_pct_graph', size = 10)
plt.xlabel('judge', size = 10)
plt.ylabel('pct', size = 10)
plt.xticks(size = 10)
plt.yticks(size = 10)
plt.show()

# %%
# judges who we should explore more
most
# Out:
# ['Virginia M. Ward, J.',
#  'Elizabeth M. Fahey, J.',
#  'Timothy F. Sullivan, J.',
#  'Linda E. Giles, J.',
#  'Robert J. Kane, J.',
#  'Garry V. Inge, J.',
#  'John C. Cratsley, J.',
#  'Robert C. Cosgrove, J.',
#  'Robert A. Cornetta, J.',
#  'Christopher J. Muse, J.',
#  'Geraldine S. Hines, J.']
